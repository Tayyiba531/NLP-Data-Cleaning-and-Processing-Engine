# %%
import nltk
nltk.download('punkt_tab')
from nltk.tokenize import word_tokenize, sent_tokenize
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Al Madina
# [nltk_data]     Computer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# Tonizing convert text into smaller units

# %% [markdown]
# Sentance tokenization

# %%
sentence = "Her cat's name is Luna. Her dog's name is Mat"
sent_tokenize(sentence)
# Out:
# ["Her cat's name is Luna.", "Her dog's name is Mat"]

# %%
sentence = "Her cat's name is Luna. Her dog's name is Mat"
word_tokenize(sentence)
# Out:
# ['Her',
#  'cat',
#  "'s",
#  'name',
#  'is',
#  'Luna',
#  '.',
#  'Her',
#  'dog',
#  "'s",
#  'name',
#  'is',
#  'Mat']
