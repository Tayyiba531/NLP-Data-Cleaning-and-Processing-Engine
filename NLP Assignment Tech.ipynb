# %%
#Lowercase
text = "In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. Whenever you feel like criticizing any one, he told me, just remember that all the people in this world haven’t had the advantages that you’ve had. He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores"
print(text)
# Out:
# In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. Whenever you feel like criticizing any one, he told me, just remember that all the people in this world haven’t had the advantages that you’ve had. He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# %%
text_lower = text.lower()

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Al Madina
# [nltk_data]     Computer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Al Madina
# [nltk_data]     Computer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text_no_punct = text_lower.translate(str.maketrans('', '', string.punctuation))

# Tokenize into words
tokens = word_tokenize(text_no_punct)

# Remove stop words
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word not in stop_words]

# Step 3: Print the processed text
print("Original Text:")
print(text)

print("\nProcessed Text (lowercase, no punctuation, no stop words):")
print(' '.join(filtered_tokens))
# Out:
# Original Text:
# In my younger and more vulnerable years my father gave me some advice that I've been turning over in my mind ever since. Whenever you feel like criticizing any one, he told me, just remember that all the people in this world haven’t had the advantages that you’ve had. He didn’t say any more, but we’ve always been unusually communicative in a reserved way, and I understood that he meant a great deal more than that. In consequence, I’m inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores
#
# Processed Text (lowercase, no punctuation, no stop words):
# younger vulnerable years father gave advice ive turning mind ever since whenever feel like criticizing one told remember people world ’ advantages ’ ’ say ’ always unusually communicative reserved way understood meant great deal consequence ’ inclined reserve judgments habit opened many curious natures also made victim veteran bores
